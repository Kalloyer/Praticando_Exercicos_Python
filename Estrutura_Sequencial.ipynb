# %% [markdown]
# # Lista de Exercícios Estrutura Sequencial
#
# --> [Link da Lista](https://wiki.python.org.br/ListaDeExercicios) <--
#
# 1. Faça um Programa que mostre a mensagem **"Alo mundo"** na tela.
#
# 2. Faça um Programa que peça um número e então mostre a mensagem:
#    **O número informado foi [número].**
#
# 3. Faça um Programa que peça dois números e imprima a soma.
#
# 4. Faça um Programa que peça as 4 notas bimestrais e mostre a média.
#
# 5. Faça um Programa que converta metros para centímetros.
#
# 6. Faça um Programa que peça o raio de um círculo, calcule e mostre sua área.
#
# 7. Faça um Programa que calcule a área de um quadrado e, em seguida, mostre o dobro desta área para o usuário.
#
# 8. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.
#    Calcule e mostre o total do seu salário no referido mês.
#
# 9. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius:
#    **C = 5 * ((F-32) / 9)**
#
# 10. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
#
# 11. Faça um Programa que peça 2 números inteiros e 1 número real. Calcule e mostre:
#     - O produto do dobro do primeiro com metade do segundo.
#     - A soma do triplo do primeiro com o terceiro.
#     - O terceiro elevado ao cubo.
#
# 12. Tendo como dados de entrada a altura de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a fórmula:
#     **(72.7 * altura) - 58**
#
# 13. Tendo como dado de entrada a altura (**h**) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as fórmulas:
#     - Para homens: **(72.7 * h) - 58**
#     - Para mulheres: **(62.1 * h) - 44.7**
#
# 14. João Papo-de-Pescador comprou um microcomputador para controlar o rendimento diário de seu trabalho.
#     Toda vez que ele traz um peso de peixes maior que o limite de 50 quilos, deve pagar uma multa de R$ 4,00 por quilo excedente.
#     Faça um programa que leia o peso dos peixes, calcule o excesso e a multa.
#     Imprima os dados do programa com as mensagens adequadas.
#
# 15. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.
#     Calcule e mostre o total do seu salário no referido mês, sabendo-se que são descontados:
#     - 11% para o Imposto de Renda.
#     - 8% para o INSS.
#     - 5% para o sindicato.
#
#     O programa deve exibir:
#     - Salário Bruto.
#     - Quanto foi pago ao INSS.
#     - Quanto foi pago ao sindicato.
#     - Salário Líquido.
#
#     Fórmula: **Salário Líquido = Salário Bruto - Descontos**
#
# 16. Faça um programa para uma loja de tintas.
#     - O programa deverá pedir o tamanho em metros quadrados da área a ser pintada.
#     - Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados.
#     - A tinta é vendida em latas de 18 litros, custando R$ 80,00 cada.
#
#     Informe ao usuário a quantidade de latas de tinta a serem compradas e o preço total.
#
# 17. Faça um Programa para uma loja de tintas.
#     - O programa deverá pedir o tamanho em metros quadrados da área a ser pintada.
#     - Considere que a cobertura da tinta é de 1 litro para cada 6 metros quadrados.
#     - A tinta é vendida em:
#       - Latas de 18 litros, custando R$ 80,00.
#       - Galões de 3,6 litros, custando R$ 25,00.
#
#     Informe ao usuário as quantidades de tinta a serem compradas e os preços nas seguintes situações:
#     - Comprar apenas latas de 18 litros.
#     - Comprar apenas galões de 3,6 litros.
#     - Misturar latas e galões de forma que o desperdício seja o menor possível.
#
#     **Obs.:** Acrescente 10% de folga e sempre arredonde os valores para cima.
#
# 18. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps).
#     Calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).

# %%
#Exercício 1
print('Olá mundo')
# Out:
# Olá mundo

# %%
#Exercício 2
numero = input('Digite um número: ')
print(f'O número informado foi {numero}')
# Out:
# Digite um número: 5
# O número informado foi 5

# %%
#Exercício 3
numero1 = int(input('Digite um número: '))
numero2 = int(input('Digite outro número: '))
soma = numero1 + numero2
print(f'A soma dos números é {soma}')
# Out:
# Digite um número:5
# Digite outro número: 5
# A soma dos números é 10

# %%
#Exercicio 4
nota1 = float(input('Digite a 1ª nota: '))
nota2 = float(input('Digite a 2ª nota: '))
nota3 = float(input('Digite a 3ª nota: '))
nota4 = float(input('Digite a 4ª nota: '))
media = (nota1 + nota2 + nota3 + nota4) / 4

print(f'A média trimestra é de {media:.1f}')
# Out:
# Digite a 1ª nota: 8
# Digite a 2ª nota: 9
# Digite a 3ª nota: 6
# Digite a 4ª nota: 8
# A média trimestra é de 7.8

# %%
#Exercicio 5
metro = float(input('Digite os metros: '))

centimetro = metro * 100

print(f'Convertendo os metros {metro:.0f} para centímetros, ficaria: {centimetro:.2f}cm.')
# Out:
# Digite os metros: 3
# Convertendo os metros 3 para centímetros, ficaria: 300.00cm.

# %%
#Exercicio 6
import math

raio = float(input('Digite o raio do círculo: '))
area = math.pi * (raio ** 2)

print(f'A área de círculo é {area:.1f}')
# Out:
# Digite o raio do círculo: 15
# A área de círculo é 706.9

# %%
#Exercicio 7
area = float(input('Digite a áreado do quadrado: '))

dobro = area ** 2

print(f'A área do quadrado é de {dobro:.2f}')
# Out:
# Digite a áreado do quadrado: 12
# A área do quadrado é de 144.00

# %%
#Exercicio 8
ganho_hora = float(input('Digite o valor ganho por hora R$: '))
trabalho_hora = int(input('Digite as horas trabalhadas: '))

salario = (ganho_hora * trabalho_hora) * 30

print(f'O total do salário no mês é de R$', salario)
# Out:
# Digite o valor ganho por hora R$: 50
# Digite as horas trabalhadas: 8
# O total do salário no mês é de R$ 12000.0

# %%
#Exercicio 9
f = float(input('Digite a temperatura em fahrenheit: '))
c = 5 * ((f-32) / 9)
print(f'A temperatura em Fahrenheit é de {f:.0f}º e em Celsius é {c:.0f}º!')
# Out:
# Digite a temperatura em fahrenheit: 50
# A temperatura em Fahrenheit é de 50º e em Celsius é 10º!

# %%
#Exercicio 10
c = float(input('Digite a temperatura em celsius: '))
f = (c * 9/5) + 32
print(f'A temperatura em Celsius é de {c:.0f}º e em é Fahrenheit {f:.0f}º!')
# Out:
# Digite a temperatura em celsius: 50
# A temperatura em Celsius é de 50º e em  é Fahrenheit 122º!

# %%
#Exercicio 11
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))
numr = float(input('Digite o terceiro número: '))

calculo1 = (num1 * 2) / num2
calculo2 = (num1 * 3) + numr
calculo3 = numr ** 3

print(f'Calculo do produto do dobro do primeiro com metade do segundo = {calculo1}')
print(f'Calculo da soma do triplo do primeiro com o terceiro = {calculo2}')
print(f'Calculo do terceiro elevado ao cubo = {calculo3:.2f}')
# Out:
# Digite o primeiro número: 5
# Digite o segundo número: 5
# Digite o terceiro número: 5.8
# Calculo do produto do dobro do primeiro com metade do segundo = 2.0
# Calculo da soma do triplo do primeiro com o terceiro = 20.8
# Calculo do terceiro elevado ao cubo = 195.112

# %%
#Exercicio 12
altura = float(input('Digite seu tamanho em metros: '))
peso_ideal = (72.7*altura) - 58
print(f'Seu peso ideal seria de {peso_ideal:.2f}')
# Out:
# Digite seu tamanho em metros: 1.91
# Seu peso ideal seria de 80.86

# %%
#Exercicio 13
opcao = str(input('Digite seu sexo [M/F]: ')).upper()
altura = float(input('Digite seu tamanho em metros: '))

if opcao == 'F':
  f = (62.1 * altura) - 44.7
  print(f'Seu peso ideal seria de {f:.2f}kg')
elif opcao == 'Mm':
  m = (72.7 * altura) - 58
  print(f'Seu peso ideal seria de {m:.2f}kg')
# Out:
# Digite seu sexo [M/F]: f
# Digite seu tamanho em metros: 1.91
# Seu peso ideal seria de 73.91kg

# %%
#Exercicio 14
peso = float(input('Digite o peso em kilo dos peixes: '))

if peso > 50:
    excesso = peso - 50
    multa = excesso * 4
    print('A multa pelo excesso de kilos de peixe é de R$', multa)
else:
  print('Não há multa pelo excesso de kilos de peixe!')
# Out:
# Digite o peso em kilo dos peixes: 58.5
# A multa pelo excesso de kilos de peixe é de R$ 34.0

# %%
#Exercicio 15
ganha_hora = float(input('Digite o valor ganho por hora R$ '))
hora_trabalhada = int(input('Digite as horas trabalhadas no mês: '))

salario_bruto = ganha_hora * hora_trabalhada
ir =0.11 * salario_bruto
inss = 0.08 * salario_bruto
sindicato = 0.05 * salario_bruto
salario_liquido = salario_bruto - (ir + inss + sindicato)

print(f"""Salário Bruto: R${salario_bruto:.2f}
IR(11%): R${ir:.2f}
INSS(8%): R${inss:.2f}
Sindicato(5%): R${sindicato:.2f}
Salário Liquido: R${salario_liquido:.2f}
""")
# Out:
# Digite o valor ganho por hora R$ 18.75
# Digite as horas trabalhadas no mês: 160
# Salário Bruto: R$3000.00
# IR(11%): R$330.00
# INSS(8%): R$240.00
# Sindicato(5%): R$150.00
# Salário Liquido: R$2280.00

# %%
#Exercicio 16
import math
area = float(input('Digite os metros quadrados da area: '))

qlatas = (area / 3) / 18
ptotal = round(qlatas) * 80

print(f"""Quantidade de latas para serem compradas: {qlatas:.0f} unidades.
Preço total das latas de tintas R${ptotal:.2f}""")
# Out:
# Digite os metros quadrados da area: 300
# Quantidade de latas para serem compradas: 6 unidades.
# Preço total das latas de tintas R$480.00

# %%
#Exercicio 17
import math

area = float(input('Digite os metros quadrados da area: '))
litros = area / 6 * 1.1
latas = litros / 18
galoes = litros / 3.6

if latas % 18 != 0:
  latas += 1
  platas = latas * 80
if galoes % 3.6 != 0:
  galoes += 1
  pgaloes = galoes * 25

mlata = int(litros / 18)
mgaloes = int((litros - (mlata * 18)) / 3.6)

if litros - (mlata*18) % 3.6 != 0:
  mgaloes += 1
gtotal = (mlata * 80) + (mgaloes * 25)

print(f"""
Total de litros necessários para pintar: {litros:.0f}L
Apenas latas de 18 litros: {latas:.0f}un, valor total de R${platas:.2f}
Apenas galoes de 3.6 litros: {galoes:.0f}un, valor total de R${pgaloes:.2f}
Mistura: {mlata:.0f} latas + {mgaloes:.0f} galões, valor total de R${gtotal:.2f}""")
# Out:
# Digite os metros quadrados da area: 300
#
# Total de litros necessários para pintar: 55L
# Apenas latas de 18 litros: 4un, valor total de R$324.44
# Apenas galoes de 3.6 litros: 16un, valor total de R$406.94
# Mistura: 3 latas + 1 galões, valor total de R$265.00

# %%
#Exercicio 18
download = float(input('Digite o tamanho do arquivo em (Mb): '))
wifi = int(input('Digite sua velocidade de internet em (Mbps): '))

vdownload = download / (wifi / 8)
dias = int(vdownload // (24 * 3600))
vdownload %= (24 * 3600)
horas = int(vdownload // 3600)
vdownload %= 3600
minutos = int(vdownload // 60)
segundos = int(vdownload % 60)

print(f"Tempo estimado para o download: {dias} dias, {horas} horas, {minutos} minutos e {segundos} segundos.")
# Out:
# Digite o tamanho do arquivo em (Mb): 1000
# Digite sua velocidade de internet em (Mbps): 10
# Tempo estimado para o download: 0 dias, 0 horas, 13 minutos e 20 segundos.
